# %% [markdown]
# # Titanic Dataset
#
# |Variable|Definition|Key|
# |---|---|---|
# |Survived|Survival|0 = No, 1 = Yes|
# |Pclass|Ticket class|1 = 1st, 2 = 2nd, 3 = 3rd|
# |Name|Name||
# |Sex|Sex||
# |Age|Age in years	||
# |SibSp|# of siblings / spouses aboard the Titanic||
# |Parch|# of parents / children aboard the Titanic||
# |Ticket|Ticket number||
# |Fare|Passenger fare||
# |Cabin|Cabin number||
# |Embarked|Port of Embarkation|C = Cherbourg, Q = Queenstown, S = Southampton|

# %% [markdown]
# ## Import Libraries and Data
# Import Necessary Libraries

# %%
# Libraries to help with reading and manipulating data
import numpy as np
import pandas as pd

# Libraries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# to restrict the float value to 3 decimal places
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# Import The Dataset

# %%
#import data as a pandas dataframe

# Access the .csv file in Google Drive folder. The file path must be correct
data = pd.read_csv('Titanic_Dataset.csv')

# %% [markdown]
# ## Data Check
# - View the first and last rows of the dataframe
# - Determine the number of entries in the dataframe
# - Check the data types for each entry
# - Check for missing values
# - Check and remove duplicate values
# - Create a statistical summary of the numerical data

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex    Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male 22.000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female 38.000      1
# 2                               Heikkinen, Miss. Laina  female 26.000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female 35.000      1
# 4                             Allen, Mr. William Henry    male 35.000      0
# ..                                                 ...     ...    ...    ...
# 886                              Montvila, Rev. Juozas    male 27.000      0
# 887                       Graham, Miss. Margaret Edith  female 19.000      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female    NaN      1
# 889                              Behr, Mr. Karl Howell    male 26.000      0
# 890                                Dooley, Mr. Patrick    male 32.000      0
#
#      Parch            Ticket   Fare Cabin Embarked
# 0        0         A/5 21171  7.250   NaN        S
# 1        0          PC 17599 71.283   C85        C
# 2        0  STON/O2. 3101282  7.925   NaN        S
# 3        0            113803 53.100  C123        S
# 4        0            373450  8.050   NaN        S
# ..     ...               ...    ...   ...      ...
# 886      0            211536 13.000   NaN        S
# 887      0            112053 30.000   B42        S
# 888      2        W./C. 6607 23.450   NaN        S
# 889      0            111369 30.000  C148        C
# 890      0            370376  7.750   NaN        Q
#
# [891 rows x 12 columns]

# %%
data.shape
# Out:
# (891, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#        PassengerId  Survived  Pclass     Age   SibSp   Parch    Fare
# count      891.000   891.000 891.000 714.000 891.000 891.000 891.000
# mean       446.000     0.384   2.309  29.699   0.523   0.382  32.204
# std        257.354     0.487   0.836  14.526   1.103   0.806  49.693
# min          1.000     0.000   1.000   0.420   0.000   0.000   0.000
# 25%        223.500     0.000   2.000  20.125   0.000   0.000   7.910
# 50%        446.000     0.000   3.000  28.000   0.000   0.000  14.454
# 75%        668.500     1.000   3.000  38.000   1.000   0.000  31.000
# max        891.000     1.000   3.000  80.000   8.000   6.000 512.329

# %% [markdown]
# ## Question 1 - Create a dataframe containing only passengers who embarked from Southhampton

# %%
data[data["Embarked"]== 'S']
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# ..           ...       ...     ...
# 883          884         0       2
# 884          885         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
#
#                                              Name     Sex    Age  SibSp  \
# 0                         Braund, Mr. Owen Harris    male 22.000      1
# 2                          Heikkinen, Miss. Laina  female 26.000      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female 35.000      1
# 4                        Allen, Mr. William Henry    male 35.000      0
# 6                         McCarthy, Mr. Timothy J    male 54.000      0
# ..                                            ...     ...    ...    ...
# 883                 Banfield, Mr. Frederick James    male 28.000      0
# 884                        Sutehall, Mr. Henry Jr    male 25.000      0
# 886                         Montvila, Rev. Juozas    male 27.000      0
# 887                  Graham, Miss. Margaret Edith  female 19.000      0
# 888      Johnston, Miss. Catherine Helen "Carrie"  female    NaN      1
#
#      Parch            Ticket   Fare Cabin Embarked
# 0        0         A/5 21171  7.250   NaN        S
# 2        0  STON/O2. 3101282  7.925   NaN        S
# 3        0            113803 53.100  C123        S
# 4        0            373450  8.050   NaN        S
# 6        0             17463 51.862   E46        S
# ..     ...               ...    ...   ...      ...
# 883      0  C.A./SOTON 34068 10.500   NaN        S
# 884      0   SOTON/OQ 392076  7.050   NaN        S
# 886      0            211536 13.000   NaN        S
# 887      0            112053 30.000   B42        S
# 888      2        W./C. 6607 23.450   NaN        S
#
# [644 rows x 12 columns]

# %% [markdown]
# ## Question 2 - Create a dataframe containing the last 30 entries in the dataset and include only the names and cabin numbers for these passengers.

# %%
data.loc[[x for x in range(860,891)], ["Name", "Cabin"]]
# Out:
#                                                   Name        Cabin
# 861                        Giles, Mr. Frederick Edward          NaN
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...          D17
# 863                  Sage, Miss. Dorothy Edith "Dolly"          NaN
# 864                             Gill, Mr. John William          NaN
# 865                           Bystrom, Mrs. (Karolina)          NaN
# 866                       Duran y More, Miss. Asuncion          NaN
# 867               Roebling, Mr. Washington Augustus II          A24
# 868                        van Melkebeke, Mr. Philemon          NaN
# 869                    Johnson, Master. Harold Theodor          NaN
# 870                                  Balkic, Mr. Cerin          NaN
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)          D35
# 872                           Carlsson, Mr. Frans Olof  B51 B53 B55
# 873                        Vander Cruyssen, Mr. Victor          NaN
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)          NaN
# 875                   Najib, Miss. Adele Kiamie "Jane"          NaN
# 876                      Gustafsson, Mr. Alfred Ossian          NaN
# 877                               Petroff, Mr. Nedelio          NaN
# 878                                 Laleff, Mr. Kristo          NaN
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)          C50
# 880       Shelley, Mrs. William (Imanita Parrish Hall)          NaN
# 881                                 Markun, Mr. Johann          NaN
# 882                       Dahlberg, Miss. Gerda Ulrika          NaN
# 883                      Banfield, Mr. Frederick James          NaN
# 884                             Sutehall, Mr. Henry Jr          NaN
# 885               Rice, Mrs. William (Margaret Norton)          NaN
# 886                              Montvila, Rev. Juozas          NaN
# 887                       Graham, Miss. Margaret Edith          B42
# 888           Johnston, Miss. Catherine Helen "Carrie"          NaN
# 889                              Behr, Mr. Karl Howell         C148
# 890                                Dooley, Mr. Patrick          NaN

# %% [markdown]
# ## Question 3 - How many passengers travelled 1st class, 2nd class and 3rd class?

# %%
data[]

# %% [markdown]
# ## Question 4 - What was the mean age of survivors of the Titanic? What is the sum of all the ages for the survivors?

# %% [markdown]
# ## Question 5 - What percentage of the passengers were women? (women/total passengers)

# %% [markdown]
# ## Question 6: From which port did the most number of 3rd class passengers embark?

# %% [markdown]
# ## Question 7 - What percentage of women survived? ( female survivors / total women) And what percentage of men survived? (male survivors/ total men)

# %% [markdown]
# ## Question 8 - Create a table displaying the survival rates(percentage) of female and male passengers traveling in 1st, 2nd, 3rd class. (number of survivors/total number of passengers in that class of a particular class)
